# %%
pip install face_recognition
# Out:
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting face-recognition-models>=0.3.0 (from face_recognition)
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.10/dist-packages (from face_recognition) (8.1.7)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.10/dist-packages (from face_recognition) (19.24.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from face_recognition) (1.26.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from face_recognition) (11.0.0)
# Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566162 sha256=480846fae1d7a5f9c31650d1522835984c7c9db43383c78b22db8f0f3aa69b35
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face_recognition
# Successfully installed face-recognition-models-0.3.0 face_recognition-1.3.0

# %% [markdown]
# #Workflow Breakdown Brief
#
# **1. Setting Up:**
#
# *  **Libraries:** The script imports necessary libraries like `pandas` for data manipulation, `requests` for downloading videos, `cv2` for computer vision tasks, `face_recognition` for face detection and encoding, `json` for handling JSON data, and `numpy` for numerical computations.
# *  **Known Encodings:** It defines file paths for saving known face encodings in a JSON format (`encoding_file`). It also includes functions to save and load these encodings (`save_encodings_json` and `load_encodings_json`).
# *  **Downloading Videos:** The `download_video` function retrieves videos from URLs specified in the excel file.
#
# **2. Processing Videos:**
#
# *  **Read Excel Data:** The script reads an excel file (`excel_file`), assuming it has columns like "Video URL" and "Performance" (potentially for further analysis).
# *  **Iterate Through Videos:** It loops through each row in the DataFrame.
#   * **Download and Open Video:** For each video URL, it downloads the video and opens a video capture object (`cap`) using OpenCV's `cv2.VideoCapture`.
#   * **Initialize Counters:** It initializes counters for unique faces detected in the entire process (`unique_faces_count`) and new faces detected in the current video (`new_faces_count`). It also creates an empty list (`faces_in_video`) to store detected faces for the current video and a set (`current_video_faces`) to track unique faces within the video.
#   * **Process Video Frames:** It enters a loop that reads video frames one by one using `cap.read()`.
#     * **Check for Success:** It checks if the frame is read successfully. If not, it handles the error and breaks the loop if the video ends, or continues if there's a reading issue.
#     * **Resize and Convert Frame:** It resizes and converts the frame to RGB format for face recognition.
#     * **Face Detection:** The core face detection part uses `face_recognition.face_locations` to identify face locations within the frame using a pre-trained CNN model ("cnn").
#     * **No Faces Detected:** If no faces are found in the frame, the loop continues to the next frame.
#     * **Face Encoding:** For each detected face location, it extracts facial features (encodings) using `face_recognition.face_encodings`.
#
# **3. Face Matching and Analysis:**
#
# *  **Matching with Known Faces:** If there are known face encodings (`encodeDictKnown`), it iterates through each detected face and its encoding:
#     * **Face Distance Calculation:** It calculates the "face distance" between the current face encoding and all known encodings using `face_recognition.face_distance`. This distance represents the similarity between faces.
#     * **Matching Threshold:** It finds the minimum distance (closest match) and compares it to a threshold (0.60 in this case). If the distance is lower than the threshold, it considers it a match.
#     * **Matched Name Retrieval:** If a match is found, it retrieves the name associated with the closest known encoding.
# *  **New Face Detection:**
#     * **No Match:** If no match is found, it signifies a new face. It creates a unique name for the person (e.g., "person_X") and adds the new face encoding to the `encodeDictKnown` dictionary.
#     * **Updating Counters:** It increments the `unique_faces_count` (total unique faces) and `new_faces_count` (new faces in this video).
# *  **Tracking Faces in Video:** It adds the detected name (matched or unique) to the `current_video_faces` set to avoid duplicates within the current video. It then appends the name to the `faces_in_video` list.
#
# **4. Saving and Reporting:**
#
# *  **Save Encodings:** After processing all frames in the video, it saves the updated `encodeDictKnown` dictionary (including potentially new faces) back to the JSON file.
# *  **New Faces and Detected People:** It appends the `new_faces_count` and a comma-separated string of detected faces (`faces_in_video`) for the current video to separate lists (`new_faces_detected` and `people_detected`).
# *  **Video Cleanup:** It releases the video capture resources and deletes the downloaded video file to save space.
# *  **Reporting:** It prints a message indicating the video has been processed and deleted, along with the total number of unique faces detected in that video.
#
# **5. Updating Excel Data:**
#
# * **Length Check:** The script ensures the lengths of `new_faces_detected` and `people_detected` lists match the number of rows in the DataFrame.
# * **Adding New Columns:** If the lengths match, it adds two new columns to the DataFrame:
#     * "People Detected": This column stores the comma-separated list of faces detected in each video (from `people_detected`).
#     * "Number of New Faces Detected": This column stores the count of new faces detected in each video (from `new_faces_detected`).
# * **Mismatch Handling:** If the lengths don't match, it prints an error message indicating an issue during face detection.
# * **Save Updated Excel:** Finally, it creates a new Excel file with the updated data (`output_excel_file`) using the pandas `to_excel` method.
#
# **Additional Notes:**
#
# * The script utilizes a pre-trained CNN model ("cnn") for face detection. This model is likely part of the `face_recognition` library.
# * The threshold value (0.60) for considering a face a match can be adjusted based on the desired accuracy and application.
# * The script demonstrates a basic implementation of face recognition with known encodings stored in a JSON file. More advanced approaches might involve database storage and retrieval of encodings.

# %%
import pandas as pd
import requests
import cv2
import face_recognition
import json
import numpy as np
import os

# File path to save known encodings
encoding_file = "/content/known_faces.json"

# Function to save encodings with names to a JSON file
def save_encodings_json(encodings_dict, file_path):
    # Convert numpy arrays to lists for JSON serialization
    encodings_dict_serializable = {key: encoding.tolist() for key, encoding in encodings_dict.items()}
    with open(file_path, 'w') as f:
        json.dump(encodings_dict_serializable, f)
    print(f"Encodings saved to {file_path}")

# Function to load encodings from a JSON file
def load_encodings_json(file_path):
    try:
        with open(file_path, 'r') as f:
            encodings_dict = json.load(f)
        print(f"Encodings loaded from {file_path}")
        # Convert lists back to numpy arrays
        encodings_dict = {key: np.array(value) for key, value in encodings_dict.items()}
        return encodings_dict
    except FileNotFoundError:
        print(f"No encoding file found at {file_path}. Starting with an empty dictionary.")
        return {}

# Download video from URL
def download_video(url, filename):
    response = requests.get(url, stream=True)
    if response.status_code == 200:
        with open(filename, 'wb') as f:
            for chunk in response.iter_content(chunk_size=1024):
                if chunk:
                    f.write(chunk)
        print(f"Downloaded video from {url}")
    else:
        print(f"Failed to download video from {url}")

# Load known encodings if available
encodeDictKnown = load_encodings_json(encoding_file)

# If encodeDictKnown is not a dictionary, initialize it as one
if not isinstance(encodeDictKnown, dict):
    encodeDictKnown = {}

# Read Excel file
excel_file = "/content/Assignment Data.xlsx"
df = pd.read_excel(excel_file)

# List to store new faces detected for each video
new_faces_detected = []
people_detected = []

# Process each row in the DataFrame (assuming columns: 'Video URL' and 'Performance')
for index, row in df.iterrows():
    video_url = row['Video URL']
    performance = row['Performance']  # You can use this if needed for analysis

    # Generate a filename based on the URL (you can customize this)
    video_filename = f"video_{index}.mp4"

    # Download the video
    download_video(video_url, video_filename)

    # Initialize video capture
        # Initialize video capture
    cap = cv2.VideoCapture(video_filename)

    if not cap.isOpened():
        print(f"Error: Could not open video file {video_filename}.")
        continue

    unique_faces_count = len(encodeDictKnown)  # Initialize counter with existing encodings
    new_faces_count = 0  # Counter for new faces in the current video
    faces_in_video = []  # To keep track of faces detected in the current video

    # Persistent set for tracking detected faces in the video
    current_video_faces = set()

    while True:
        success, img = cap.read()

        if not success:
            if cap.get(cv2.CAP_PROP_POS_FRAMES) >= cap.get(cv2.CAP_PROP_FRAME_COUNT):
                print(f"Video {video_filename} has ended.")
            else:
                print("Error occurred while reading the video.")
            break

        imgS = cv2.resize(img, (0, 0), None, 0.45, 0.45)
        imgS = cv2.cvtColor(imgS, cv2.COLOR_BGR2RGB)

        faceCurFrame = face_recognition.face_locations(imgS, model="cnn")

        if len(faceCurFrame) == 0:
            continue

        encodeCurFrame = face_recognition.face_encodings(imgS, faceCurFrame)

        for faceloc, encoding in zip(faceCurFrame, encodeCurFrame):
            is_match = False
            matched_name = None  # Variable to store the name of the matched person

            # Check if there are any known encodings
            if encodeDictKnown:
                # Compare the current encoding with known encodings
                face_distances = face_recognition.face_distance(list(encodeDictKnown.values()), encoding)
                min_distance = min(face_distances)  # Find the closest match
                if min_distance < 0.60:  # Threshold for considering it a match
                    matched_index = np.argmin(face_distances)  # Index of the closest match
                    matched_name = list(encodeDictKnown.keys())[matched_index]  # Retrieve the name
                    is_match = True

            if is_match:
                # Add matched name to the current video set if not already added
                if matched_name not in current_video_faces:
                    current_video_faces.add(matched_name)  # Add to the set of detected faces
                    faces_in_video.append(matched_name)  # Append to the list of faces for the video
                    print(f"Matched with {matched_name} (distance: {min_distance:.2f})")
            else:
                # If no match, create a new unique name for the person
                unique_name = f"person_{unique_faces_count + 1}"
                encodeDictKnown[unique_name] = encoding
                unique_faces_count += 1
                new_faces_count += 1
                current_video_faces.add(unique_name)  # Add to the set of detected faces
                faces_in_video.append(unique_name)  # Append to the list of faces for the video
                print(f"New unique face detected at location {faceloc}! Total unique faces: {unique_faces_count}")

    # Save updated encodings to the JSON file after processing the current video
    save_encodings_json(encodeDictKnown, encoding_file)

    # Add the number of new faces detected and the faces detected list to the respective lists
    new_faces_detected.append(new_faces_count)
    people_detected.append(', '.join(faces_in_video))  # Join faces with comma

    # Release video capture resources and delete the video to save space
    cap.release()
    os.remove(video_filename)
    print(f"Video {video_filename} processed and deleted.")

    print(f"Total number of unique faces detected in {video_filename}: {unique_faces_count}")

# Ensure lengths match before adding columns
if len(new_faces_detected) == len(df) and len(people_detected) == len(df):
    # Add the new columns to the DataFrame
    df['People Detected'] = people_detected
    df['Number of New Faces Detected'] = new_faces_detected
else:
    print("Mismatch in lengths. Something went wrong while detecting faces.")

# Create the new Excel file with the updated data
output_excel_file = "updated_video_performance_with_people.xlsx"
df.to_excel(output_excel_file, index=False)

print(f"Updated Excel file saved as {output_excel_file}")
# Out:
# No encoding file found at /content/known_faces.json. Starting with an empty dictionary.
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-999607261342550
# New unique face detected at location (293, 176, 333, 137)! Total unique faces: 1
# Video video_0.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_0.mp4 processed and deleted.
# Total number of unique faces detected in video_0.mp4: 1
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-997580728807604
# Video video_1.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_1.mp4 processed and deleted.
# Total number of unique faces detected in video_1.mp4: 1
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-992418235673669
# New unique face detected at location (384, 156, 441, 100)! Total unique faces: 2
# New unique face detected at location (397, 148, 437, 109)! Total unique faces: 3
# New unique face detected at location (393, 88, 433, 49)! Total unique faces: 4
# New unique face detected at location (166, 251, 248, 169)! Total unique faces: 5
# Video video_2.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_2.mp4 processed and deleted.
# Total number of unique faces detected in video_2.mp4: 5
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-992064161877405
# New unique face detected at location (150, 193, 232, 111)! Total unique faces: 6
# New unique face detected at location (197, 250, 244, 203)! Total unique faces: 7
# Matched with person_2 (distance: 0.60)
# New unique face detected at location (246, 223, 314, 154)! Total unique faces: 8
# Video video_3.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_3.mp4 processed and deleted.
# Total number of unique faces detected in video_3.mp4: 8
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-991636695150147
# Matched with person_1 (distance: 0.00)
# Video video_4.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_4.mp4 processed and deleted.
# Total number of unique faces detected in video_4.mp4: 8
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-989969399547901
# New unique face detected at location (384, 240, 431, 193)! Total unique faces: 9
# Matched with person_4 (distance: 0.58)
# New unique face detected at location (389, 172, 429, 133)! Total unique faces: 10
# Video video_5.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_5.mp4 processed and deleted.
# Total number of unique faces detected in video_5.mp4: 10
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-989930303148492
# Video video_6.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_6.mp4 processed and deleted.
# Total number of unique faces detected in video_6.mp4: 10
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-989654009083459
# Video video_7.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_7.mp4 processed and deleted.
# Total number of unique faces detected in video_7.mp4: 10
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-989600295478567
# Matched with person_1 (distance: 0.00)
# Video video_8.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_8.mp4 processed and deleted.
# Total number of unique faces detected in video_8.mp4: 10
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-989284361966196
# Matched with person_1 (distance: 0.00)
# Video video_9.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_9.mp4 processed and deleted.
# Total number of unique faces detected in video_9.mp4: 10
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-988185795921355
# Matched with person_1 (distance: 0.00)
# Video video_10.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_10.mp4 processed and deleted.
# Total number of unique faces detected in video_10.mp4: 10
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-987643572956494
# Matched with person_3 (distance: 0.54)
# Matched with person_10 (distance: 0.55)
# Matched with person_6 (distance: 0.58)
# New unique face detected at location (22, 214, 120, 116)! Total unique faces: 11
# Matched with person_2 (distance: 0.53)
# New unique face detected at location (0, 226, 46, 144)! Total unique faces: 12
# New unique face detected at location (0, 209, 53, 141)! Total unique faces: 13
# Video video_11.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_11.mp4 processed and deleted.
# Total number of unique faces detected in video_11.mp4: 13
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-987287402378278
# Video video_12.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_12.mp4 processed and deleted.
# Total number of unique faces detected in video_12.mp4: 13
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-987232088920289
# Matched with person_1 (distance: 0.00)
# Video video_13.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_13.mp4 processed and deleted.
# Total number of unique faces detected in video_13.mp4: 13
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-986360206629277
# Video video_14.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_14.mp4 processed and deleted.
# Total number of unique faces detected in video_14.mp4: 13
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-983335896508749
# New unique face detected at location (160, 214, 217, 157)! Total unique faces: 14
# Matched with person_12 (distance: 0.55)
# New unique face detected at location (216, 212, 263, 164)! Total unique faces: 15
# New unique face detected at location (211, 226, 258, 179)! Total unique faces: 16
# Matched with person_4 (distance: 0.52)
# Matched with person_2 (distance: 0.47)
# New unique face detected at location (288, 221, 335, 174)! Total unique faces: 17
# Matched with person_8 (distance: 0.59)
# New unique face detected at location (154, 208, 211, 151)! Total unique faces: 18
# Video video_15.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_15.mp4 processed and deleted.
# Total number of unique faces detected in video_15.mp4: 18
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-978448136455993
# Matched with person_1 (distance: 0.00)
# Video video_16.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_16.mp4 processed and deleted.
# Total number of unique faces detected in video_16.mp4: 18
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-977008307250628
# Matched with person_1 (distance: 0.00)
# Video video_17.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_17.mp4 processed and deleted.
# Total number of unique faces detected in video_17.mp4: 18
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-975523146942238
# Video video_18.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_18.mp4 processed and deleted.
# Total number of unique faces detected in video_18.mp4: 18
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-967731231014052
# Matched with person_1 (distance: 0.00)
# Video video_19.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_19.mp4 processed and deleted.
# Total number of unique faces detected in video_19.mp4: 18
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-966715248087290
# Matched with person_1 (distance: 0.00)
# Video video_20.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_20.mp4 processed and deleted.
# Total number of unique faces detected in video_20.mp4: 18
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-966458824582483
# Matched with person_1 (distance: 0.00)
# Video video_21.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_21.mp4 processed and deleted.
# Total number of unique faces detected in video_21.mp4: 18
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-966019214364727
# Matched with person_1 (distance: 0.00)
# Video video_22.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_22.mp4 processed and deleted.
# Total number of unique faces detected in video_22.mp4: 18
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-965108935263649
# New unique face detected at location (283, 178, 330, 131)! Total unique faces: 19
# New unique face detected at location (258, 179, 315, 123)! Total unique faces: 20
# New unique face detected at location (177, 266, 234, 209)! Total unique faces: 21
# Matched with person_3 (distance: 0.53)
# Matched with person_15 (distance: 0.52)
# Matched with person_12 (distance: 0.57)
# New unique face detected at location (192, 168, 239, 121)! Total unique faces: 22
# New unique face detected at location (237, 56, 277, 17)! Total unique faces: 23
# Matched with person_4 (distance: 0.52)
# Video video_23.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_23.mp4 processed and deleted.
# Total number of unique faces detected in video_23.mp4: 23
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-964733417506862
# Video video_24.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_24.mp4 processed and deleted.
# Total number of unique faces detected in video_24.mp4: 23
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-963303392509872
# Matched with person_11 (distance: 0.42)
# Matched with person_4 (distance: 0.51)
# Matched with person_20 (distance: 0.49)
# Matched with person_3 (distance: 0.54)
# Matched with person_13 (distance: 0.54)
# Matched with person_12 (distance: 0.55)
# Matched with person_6 (distance: 0.58)
# Video video_25.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_25.mp4 processed and deleted.
# Total number of unique faces detected in video_25.mp4: 23
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-960884234555681
# Matched with person_8 (distance: 0.46)
# Video video_26.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_26.mp4 processed and deleted.
# Total number of unique faces detected in video_26.mp4: 23
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-958774641659407
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_27.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_27.mp4 processed and deleted.
# Total number of unique faces detected in video_27.mp4: 23
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-958675741960412
# Matched with person_1 (distance: 0.00)
# Video video_28.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_28.mp4 processed and deleted.
# Total number of unique faces detected in video_28.mp4: 23
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-958267042213267
# Matched with person_1 (distance: 0.00)
# Video video_29.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_29.mp4 processed and deleted.
# Total number of unique faces detected in video_29.mp4: 23
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-954832972830686
# Matched with person_9 (distance: 0.58)
# Matched with person_15 (distance: 0.57)
# New unique face detected at location (265, 64, 305, 25)! Total unique faces: 24
# Matched with person_13 (distance: 0.58)
# Matched with person_11 (distance: 0.54)
# New unique face detected at location (257, 240, 297, 201)! Total unique faces: 25
# Matched with person_3 (distance: 0.57)
# Matched with person_7 (distance: 0.60)
# Matched with person_16 (distance: 0.57)
# Video video_30.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_30.mp4 processed and deleted.
# Total number of unique faces detected in video_30.mp4: 25
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-954440782897187
# Video video_31.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_31.mp4 processed and deleted.
# Total number of unique faces detected in video_31.mp4: 25
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-951885082053340
# Video video_32.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_32.mp4 processed and deleted.
# Total number of unique faces detected in video_32.mp4: 25
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-951491629353387
# Matched with person_1 (distance: 0.00)
# Video video_33.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_33.mp4 processed and deleted.
# Total number of unique faces detected in video_33.mp4: 25
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-946181943065342
# Matched with person_1 (distance: 0.00)
# Video video_34.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_34.mp4 processed and deleted.
# Total number of unique faces detected in video_34.mp4: 25
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-944981830978756
# Matched with person_16 (distance: 0.52)
# Matched with person_2 (distance: 0.54)
# Matched with person_8 (distance: 0.52)
# Matched with person_4 (distance: 0.55)
# Video video_35.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_35.mp4 processed and deleted.
# Total number of unique faces detected in video_35.mp4: 25
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-944755280756437
# Matched with person_1 (distance: 0.00)
# Video video_36.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_36.mp4 processed and deleted.
# Total number of unique faces detected in video_36.mp4: 25
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-944160410298140
# Matched with person_1 (distance: 0.00)
# Video video_37.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_37.mp4 processed and deleted.
# Total number of unique faces detected in video_37.mp4: 25
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-942779243913664
# Matched with person_24 (distance: 0.26)
# Matched with person_25 (distance: 0.39)
# Matched with person_3 (distance: 0.51)
# New unique face detected at location (229, 256, 269, 217)! Total unique faces: 26
# Matched with person_10 (distance: 0.55)
# Video video_38.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_38.mp4 processed and deleted.
# Total number of unique faces detected in video_38.mp4: 26
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-942524046763053
# Matched with person_1 (distance: 0.00)
# Video video_39.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_39.mp4 processed and deleted.
# Total number of unique faces detected in video_39.mp4: 26
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-940634710428411
# Matched with person_1 (distance: 0.00)
# Video video_40.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_40.mp4 processed and deleted.
# Total number of unique faces detected in video_40.mp4: 26
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-939795907980426
# Matched with person_4 (distance: 0.56)
# Matched with person_12 (distance: 0.58)
# New unique face detected at location (177, 116, 217, 77)! Total unique faces: 27
# Video video_41.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_41.mp4 processed and deleted.
# Total number of unique faces detected in video_41.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-938232524809973
# Matched with person_1 (distance: 0.34)
# Video video_42.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_42.mp4 processed and deleted.
# Total number of unique faces detected in video_42.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-937508703912579
# Matched with person_1 (distance: 0.00)
# Video video_43.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_43.mp4 processed and deleted.
# Total number of unique faces detected in video_43.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-937410954343974
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_44.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_44.mp4 processed and deleted.
# Total number of unique faces detected in video_44.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-935558767885747
# Matched with person_1 (distance: 0.00)
# Video video_45.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_45.mp4 processed and deleted.
# Total number of unique faces detected in video_45.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-935530867630269
# Matched with person_1 (distance: 0.00)
# Video video_46.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_46.mp4 processed and deleted.
# Total number of unique faces detected in video_46.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-935168780798574
# Matched with person_1 (distance: 0.00)
# Video video_47.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_47.mp4 processed and deleted.
# Total number of unique faces detected in video_47.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-933913194646448
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_48.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_48.mp4 processed and deleted.
# Total number of unique faces detected in video_48.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-933773150951550
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_49.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_49.mp4 processed and deleted.
# Total number of unique faces detected in video_49.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-932703258597949
# Matched with person_19 (distance: 0.29)
# Matched with person_21 (distance: 0.13)
# Matched with person_25 (distance: 0.54)
# Matched with person_20 (distance: 0.12)
# Matched with person_15 (distance: 0.52)
# Matched with person_11 (distance: 0.53)
# Matched with person_12 (distance: 0.58)
# Matched with person_22 (distance: 0.13)
# Matched with person_23 (distance: 0.24)
# Matched with person_3 (distance: 0.57)
# Matched with person_4 (distance: 0.53)
# Matched with person_5 (distance: 0.58)
# Video video_50.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_50.mp4 processed and deleted.
# Total number of unique faces detected in video_50.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-932296771464171
# Video video_51.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_51.mp4 processed and deleted.
# Total number of unique faces detected in video_51.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-932085787962122
# Matched with person_1 (distance: 0.00)
# Video video_52.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_52.mp4 processed and deleted.
# Total number of unique faces detected in video_52.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-932038864470963
# Matched with person_1 (distance: 0.00)
# Video video_53.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_53.mp4 processed and deleted.
# Total number of unique faces detected in video_53.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-930116227971248
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_54.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_54.mp4 processed and deleted.
# Total number of unique faces detected in video_54.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-929830031529018
# Matched with person_1 (distance: 0.00)
# Video video_55.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_55.mp4 processed and deleted.
# Total number of unique faces detected in video_55.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-929511878466995
# Matched with person_9 (distance: 0.41)
# Matched with person_10 (distance: 0.27)
# Video video_56.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_56.mp4 processed and deleted.
# Total number of unique faces detected in video_56.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-929300948587514
# Matched with person_2 (distance: 0.56)
# Video video_57.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_57.mp4 processed and deleted.
# Total number of unique faces detected in video_57.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-925596815118953
# Matched with person_1 (distance: 0.00)
# Video video_58.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_58.mp4 processed and deleted.
# Total number of unique faces detected in video_58.mp4: 27
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-925260332281638
# Matched with person_11 (distance: 0.53)
# Matched with person_5 (distance: 0.54)
# Matched with person_22 (distance: 0.58)
# Matched with person_6 (distance: 0.53)
# Matched with person_24 (distance: 0.56)
# Matched with person_12 (distance: 0.53)
# Matched with person_26 (distance: 0.56)
# New unique face detected at location (47, 181, 115, 113)! Total unique faces: 28
# Video video_59.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_59.mp4 processed and deleted.
# Total number of unique faces detected in video_59.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-924865635226814
# Video video_60.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_60.mp4 processed and deleted.
# Total number of unique faces detected in video_60.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-924585008982148
# Matched with person_1 (distance: 0.00)
# Video video_61.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_61.mp4 processed and deleted.
# Total number of unique faces detected in video_61.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-621652523105267
# Video video_62.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_62.mp4 processed and deleted.
# Total number of unique faces detected in video_62.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-621266003076530
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_63.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_63.mp4 processed and deleted.
# Total number of unique faces detected in video_63.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-620702145697389
# Video video_64.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_64.mp4 processed and deleted.
# Total number of unique faces detected in video_64.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-620154813059921
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_65.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_65.mp4 processed and deleted.
# Total number of unique faces detected in video_65.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-618555366744628
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_66.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_66.mp4 processed and deleted.
# Total number of unique faces detected in video_66.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-6174004652651971
# Matched with person_1 (distance: 0.00)
# Video video_67.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_67.mp4 processed and deleted.
# Total number of unique faces detected in video_67.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-617288786873081
# Video video_68.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_68.mp4 processed and deleted.
# Total number of unique faces detected in video_68.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-6172742522782221
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_69.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_69.mp4 processed and deleted.
# Total number of unique faces detected in video_69.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-613417017284998
# Matched with person_1 (distance: 0.00)
# Video video_70.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_70.mp4 processed and deleted.
# Total number of unique faces detected in video_70.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-613197413789434
# Video video_71.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_71.mp4 processed and deleted.
# Total number of unique faces detected in video_71.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-613152173490344
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_72.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_72.mp4 processed and deleted.
# Total number of unique faces detected in video_72.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-612555930635832
# Matched with person_1 (distance: 0.00)
# Video video_73.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_73.mp4 processed and deleted.
# Total number of unique faces detected in video_73.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-612426467555072
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_74.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_74.mp4 processed and deleted.
# Total number of unique faces detected in video_74.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-611188517518682
# Video video_75.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_75.mp4 processed and deleted.
# Total number of unique faces detected in video_75.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-6107397609317402
# Matched with person_1 (distance: 0.00)
# Video video_76.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_76.mp4 processed and deleted.
# Total number of unique faces detected in video_76.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-6096104653784047
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_77.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_77.mp4 processed and deleted.
# Total number of unique faces detected in video_77.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-606237444463640
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_78.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_78.mp4 processed and deleted.
# Total number of unique faces detected in video_78.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-605272664726548
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_79.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_79.mp4 processed and deleted.
# Total number of unique faces detected in video_79.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-6046690562050296
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_80.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_80.mp4 processed and deleted.
# Total number of unique faces detected in video_80.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-604285914607200
# Video video_81.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_81.mp4 processed and deleted.
# Total number of unique faces detected in video_81.mp4: 28
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-604041931565137
# Matched with person_19 (distance: 0.58)
# New unique face detected at location (54, 205, 153, 106)! Total unique faces: 29
# Matched with person_8 (distance: 0.57)
# Matched with person_2 (distance: 0.57)
# Matched with person_16 (distance: 0.53)
# Video video_82.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_82.mp4 processed and deleted.
# Total number of unique faces detected in video_82.mp4: 29
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-603099807587246
# Video video_83.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_83.mp4 processed and deleted.
# Total number of unique faces detected in video_83.mp4: 29
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-911926190614858
# New unique face detected at location (108, 249, 165, 192)! Total unique faces: 30
# Matched with person_3 (distance: 0.58)
# Matched with person_6 (distance: 0.57)
# Matched with person_18 (distance: 0.56)
# Matched with person_21 (distance: 0.57)
# Video video_84.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_84.mp4 processed and deleted.
# Total number of unique faces detected in video_84.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-911482386703699
# Matched with person_1 (distance: 0.00)
# Video video_85.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_85.mp4 processed and deleted.
# Total number of unique faces detected in video_85.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-911172609864769
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_86.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_86.mp4 processed and deleted.
# Total number of unique faces detected in video_86.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-910958533691058
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_87.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_87.mp4 processed and deleted.
# Total number of unique faces detected in video_87.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-909937876815529
# Matched with person_1 (distance: 0.00)
# Video video_88.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_88.mp4 processed and deleted.
# Total number of unique faces detected in video_88.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-909110383822260
# Matched with person_11 (distance: 0.53)
# Matched with person_5 (distance: 0.54)
# Matched with person_28 (distance: 0.57)
# Matched with person_6 (distance: 0.53)
# Matched with person_24 (distance: 0.56)
# Matched with person_12 (distance: 0.53)
# Matched with person_26 (distance: 0.56)
# Video video_89.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_89.mp4 processed and deleted.
# Total number of unique faces detected in video_89.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-909067460285978
# Matched with person_1 (distance: 0.00)
# Video video_90.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_90.mp4 processed and deleted.
# Total number of unique faces detected in video_90.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-907416560296782
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_91.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_91.mp4 processed and deleted.
# Total number of unique faces detected in video_91.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-906909830682725
# Matched with person_1 (distance: 0.00)
# Video video_92.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_92.mp4 processed and deleted.
# Total number of unique faces detected in video_92.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-906506897404894
# Matched with person_2 (distance: 0.44)
# Video video_93.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_93.mp4 processed and deleted.
# Total number of unique faces detected in video_93.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-905844110841635
# Matched with person_1 (distance: 0.00)
# Video video_94.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_94.mp4 processed and deleted.
# Total number of unique faces detected in video_94.mp4: 30
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-905739711170399
# New unique face detected at location (69, 124, 109, 85)! Total unique faces: 31
# Matched with person_17 (distance: 0.58)
# Matched with person_2 (distance: 0.50)
# Matched with person_10 (distance: 0.50)
# Matched with person_9 (distance: 0.49)
# Matched with person_3 (distance: 0.52)
# Matched with person_21 (distance: 0.53)
# Matched with person_6 (distance: 0.54)
# Matched with person_27 (distance: 0.56)
# Matched with person_12 (distance: 0.54)
# Matched with person_26 (distance: 0.56)
# New unique face detected at location (93, 248, 133, 209)! Total unique faces: 32
# Matched with person_28 (distance: 0.52)
# Matched with person_18 (distance: 0.56)
# New unique face detected at location (109, 224, 149, 185)! Total unique faces: 33
# Matched with person_4 (distance: 0.60)
# New unique face detected at location (65, 93, 122, 36)! Total unique faces: 34
# Matched with person_14 (distance: 0.56)
# Matched with person_20 (distance: 0.58)
# New unique face detected at location (65, 136, 105, 97)! Total unique faces: 35
# New unique face detected at location (121, 172, 161, 133)! Total unique faces: 36
# Matched with person_30 (distance: 0.49)
# Matched with person_8 (distance: 0.58)
# New unique face detected at location (116, 195, 184, 127)! Total unique faces: 37
# Video video_95.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_95.mp4 processed and deleted.
# Total number of unique faces detected in video_95.mp4: 37
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-905545323817883
# Matched with person_1 (distance: 0.00)
# Video video_96.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_96.mp4 processed and deleted.
# Total number of unique faces detected in video_96.mp4: 37
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-904815481005158
# Matched with person_2 (distance: 0.39)
# Video video_97.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_97.mp4 processed and deleted.
# Total number of unique faces detected in video_97.mp4: 37
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-904480964010630
# Video video_98.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_98.mp4 processed and deleted.
# Total number of unique faces detected in video_98.mp4: 37
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-904174908300812
# Matched with person_11 (distance: 0.42)
# Matched with person_4 (distance: 0.51)
# Matched with person_20 (distance: 0.49)
# Matched with person_3 (distance: 0.54)
# Matched with person_26 (distance: 0.50)
# Matched with person_32 (distance: 0.55)
# Matched with person_12 (distance: 0.58)
# Matched with person_13 (distance: 0.54)
# Video video_99.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_99.mp4 processed and deleted.
# Total number of unique faces detected in video_99.mp4: 37
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-903960640750545
# Video video_100.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_100.mp4 processed and deleted.
# Total number of unique faces detected in video_100.mp4: 37
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-903913985069116
# Matched with person_12 (distance: 0.55)
# Matched with person_32 (distance: 0.56)
# New unique face detected at location (105, 176, 145, 137)! Total unique faces: 38
# Matched with person_13 (distance: 0.54)
# Video video_101.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_101.mp4 processed and deleted.
# Total number of unique faces detected in video_101.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-903060767715541
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_102.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_102.mp4 processed and deleted.
# Total number of unique faces detected in video_102.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-902843234362370
# Matched with person_1 (distance: 0.00)
# Video video_103.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_103.mp4 processed and deleted.
# Total number of unique faces detected in video_103.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-902456848100089
# Matched with person_11 (distance: 0.57)
# Matched with person_5 (distance: 0.55)
# Matched with person_22 (distance: 0.58)
# Matched with person_6 (distance: 0.56)
# Matched with person_8 (distance: 0.56)
# Matched with person_26 (distance: 0.56)
# Matched with person_12 (distance: 0.53)
# Matched with person_28 (distance: 0.55)
# Video video_104.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_104.mp4 processed and deleted.
# Total number of unique faces detected in video_104.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-902309670925392
# Matched with person_1 (distance: 0.00)
# Video video_105.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_105.mp4 processed and deleted.
# Total number of unique faces detected in video_105.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-9020567984620018
# Matched with person_1 (distance: 0.00)
# Video video_106.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_106.mp4 processed and deleted.
# Total number of unique faces detected in video_106.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-901695498551491
# Video video_107.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_107.mp4 processed and deleted.
# Total number of unique faces detected in video_107.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-901272811190482
# Video video_108.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_108.mp4 processed and deleted.
# Total number of unique faces detected in video_108.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-899987727789409
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_109.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_109.mp4 processed and deleted.
# Total number of unique faces detected in video_109.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-8995485367146316
# Video video_110.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_110.mp4 processed and deleted.
# Total number of unique faces detected in video_110.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-899155277883965
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_111.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_111.mp4 processed and deleted.
# Total number of unique faces detected in video_111.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-898967424867870
# Matched with person_1 (distance: 0.00)
# Video video_112.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_112.mp4 processed and deleted.
# Total number of unique faces detected in video_112.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-898402801287469
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_113.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_113.mp4 processed and deleted.
# Total number of unique faces detected in video_113.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-898103501380741
# Matched with person_1 (distance: 0.00)
# Video video_114.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_114.mp4 processed and deleted.
# Total number of unique faces detected in video_114.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-897680994566577
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_115.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_115.mp4 processed and deleted.
# Total number of unique faces detected in video_115.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-897088088160051
# Matched with person_1 (distance: 0.00)
# Video video_116.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_116.mp4 processed and deleted.
# Total number of unique faces detected in video_116.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-896843165102015
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_117.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_117.mp4 processed and deleted.
# Total number of unique faces detected in video_117.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-896598988012982
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_118.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_118.mp4 processed and deleted.
# Total number of unique faces detected in video_118.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-896589688256009
# Matched with person_1 (distance: 0.00)
# Video video_119.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_119.mp4 processed and deleted.
# Total number of unique faces detected in video_119.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-895042408159688
# Matched with person_1 (distance: 0.00)
# Video video_120.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_120.mp4 processed and deleted.
# Total number of unique faces detected in video_120.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-894559812351386
# Matched with person_9 (distance: 0.43)
# Matched with person_10 (distance: 0.33)
# Video video_121.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_121.mp4 processed and deleted.
# Total number of unique faces detected in video_121.mp4: 38
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-894559522288371
# Matched with person_31 (distance: 0.00)
# Matched with person_34 (distance: 0.54)
# Matched with person_2 (distance: 0.50)
# ...
# Video video_230.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_230.mp4 processed and deleted.
# Total number of unique faces detected in video_230.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-690541956158254
# Matched with person_1 (distance: 0.00)
# Video video_231.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_231.mp4 processed and deleted.
# Total number of unique faces detected in video_231.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-689771035910864
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_232.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_232.mp4 processed and deleted.
# Total number of unique faces detected in video_232.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-689599909618915
# Matched with person_1 (distance: 0.00)
# Video video_233.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_233.mp4 processed and deleted.
# Total number of unique faces detected in video_233.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-689363059404444
# Matched with person_1 (distance: 0.00)
# Video video_234.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_234.mp4 processed and deleted.
# Total number of unique faces detected in video_234.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-688887926060399
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_235.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_235.mp4 processed and deleted.
# Total number of unique faces detected in video_235.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-687665956347322
# Matched with person_1 (distance: 0.00)
# Video video_236.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_236.mp4 processed and deleted.
# Total number of unique faces detected in video_236.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-687024156350870
# Matched with person_1 (distance: 0.00)
# Video video_237.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_237.mp4 processed and deleted.
# Total number of unique faces detected in video_237.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-686488653080244
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_48 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_238.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_238.mp4 processed and deleted.
# Total number of unique faces detected in video_238.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-686083626588321
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_48 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_239.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_239.mp4 processed and deleted.
# Total number of unique faces detected in video_239.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-684364333171304
# Matched with person_1 (distance: 0.00)
# Video video_240.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_240.mp4 processed and deleted.
# Total number of unique faces detected in video_240.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-684264882912286
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_241.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_241.mp4 processed and deleted.
# Total number of unique faces detected in video_241.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-6837957766319053
# Matched with person_1 (distance: 0.00)
# Video video_242.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_242.mp4 processed and deleted.
# Total number of unique faces detected in video_242.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-682791943270614
# Matched with person_1 (distance: 0.00)
# Video video_243.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_243.mp4 processed and deleted.
# Total number of unique faces detected in video_243.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-682596103528135
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_48 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_244.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_244.mp4 processed and deleted.
# Total number of unique faces detected in video_244.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-680549530054789
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_245.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_245.mp4 processed and deleted.
# Total number of unique faces detected in video_245.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-680540137074841
# Matched with person_1 (distance: 0.00)
# Video video_246.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_246.mp4 processed and deleted.
# Total number of unique faces detected in video_246.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-680162593779089
# Matched with person_1 (distance: 0.00)
# Video video_247.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_247.mp4 processed and deleted.
# Total number of unique faces detected in video_247.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-679261516829908
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_248.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_248.mp4 processed and deleted.
# Total number of unique faces detected in video_248.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-678133704039459
# Matched with person_1 (distance: 0.00)
# Video video_249.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_249.mp4 processed and deleted.
# Total number of unique faces detected in video_249.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-676770877464110
# Matched with person_1 (distance: 0.00)
# Video video_250.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_250.mp4 processed and deleted.
# Total number of unique faces detected in video_250.mp4: 48
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-6764280623620361
# Matched with person_12 (distance: 0.54)
# Matched with person_32 (distance: 0.55)
# Matched with person_15 (distance: 0.59)
# Matched with person_27 (distance: 0.60)
# Matched with person_30 (distance: 0.57)
# Matched with person_26 (distance: 0.53)
# Matched with person_22 (distance: 0.55)
# New unique face detected at location (229, 151, 286, 94)! Total unique faces: 49
# Matched with person_23 (distance: 0.53)
# Matched with person_9 (distance: 0.57)
# Matched with person_29 (distance: 0.59)
# New unique face detected at location (293, 192, 333, 153)! Total unique faces: 50
# Matched with person_8 (distance: 0.42)
# Matched with person_2 (distance: 0.47)
# Video video_251.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_251.mp4 processed and deleted.
# Total number of unique faces detected in video_251.mp4: 50
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-673961584214053
# Matched with person_1 (distance: 0.00)
# Video video_252.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_252.mp4 processed and deleted.
# Total number of unique faces detected in video_252.mp4: 50
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-6720438181324436
# New unique face detected at location (45, 264, 249, 60)! Total unique faces: 51
# Matched with person_26 (distance: 0.53)
# Matched with person_22 (distance: 0.51)
# Matched with person_15 (distance: 0.47)
# Video video_253.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_253.mp4 processed and deleted.
# Total number of unique faces detected in video_253.mp4: 51
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-671839840899900
# Matched with person_15 (distance: 0.56)
# Video video_254.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_254.mp4 processed and deleted.
# Total number of unique faces detected in video_254.mp4: 51
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-429145826826558
# New unique face detected at location (62, 99, 119, 42)! Total unique faces: 52
# Matched with person_4 (distance: 0.51)
# Matched with person_2 (distance: 0.47)
# Video video_255.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_255.mp4 processed and deleted.
# Total number of unique faces detected in video_255.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-427878012859864
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_48 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_256.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_256.mp4 processed and deleted.
# Total number of unique faces detected in video_256.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-426644026275739
# Matched with person_6 (distance: 0.00)
# Matched with person_7 (distance: 0.00)
# Matched with person_8 (distance: 0.27)
# Matched with person_2 (distance: 0.50)
# Video video_257.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_257.mp4 processed and deleted.
# Total number of unique faces detected in video_257.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-425151876539382
# Video video_258.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_258.mp4 processed and deleted.
# Total number of unique faces detected in video_258.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-424802420355057
# Video video_259.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_259.mp4 processed and deleted.
# Total number of unique faces detected in video_259.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-424394867097391
# Video video_260.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_260.mp4 processed and deleted.
# Total number of unique faces detected in video_260.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-1698824364241828
# Matched with person_41 (distance: 0.21)
# Matched with person_2 (distance: 0.49)
# Matched with person_4 (distance: 0.50)
# Matched with person_39 (distance: 0.56)
# Matched with person_3 (distance: 0.55)
# Matched with person_32 (distance: 0.52)
# Matched with person_42 (distance: 0.52)
# Matched with person_26 (distance: 0.52)
# Matched with person_7 (distance: 0.55)
# Matched with person_37 (distance: 0.49)
# Matched with person_18 (distance: 0.51)
# Matched with person_8 (distance: 0.53)
# Video video_261.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_261.mp4 processed and deleted.
# Total number of unique faces detected in video_261.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-1693566687752051
# Video video_262.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_262.mp4 processed and deleted.
# Total number of unique faces detected in video_262.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-1689212771862832
# Video video_263.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_263.mp4 processed and deleted.
# Total number of unique faces detected in video_263.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-1685108828975354
# Matched with person_15 (distance: 0.51)
# Matched with person_3 (distance: 0.47)
# Matched with person_30 (distance: 0.54)
# Matched with person_39 (distance: 0.49)
# Matched with person_18 (distance: 0.53)
# Matched with person_4 (distance: 0.56)
# Matched with person_42 (distance: 0.55)
# Matched with person_9 (distance: 0.54)
# Matched with person_2 (distance: 0.56)
# Matched with person_7 (distance: 0.59)
# Matched with person_8 (distance: 0.50)
# Matched with person_40 (distance: 0.56)
# Matched with person_47 (distance: 0.39)
# Video video_264.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_264.mp4 processed and deleted.
# Total number of unique faces detected in video_264.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-1119706949586170
# Matched with person_48 (distance: 0.41)
# Matched with person_8 (distance: 0.51)
# Matched with person_41 (distance: 0.43)
# Matched with person_40 (distance: 0.52)
# Matched with person_25 (distance: 0.49)
# Matched with person_30 (distance: 0.53)
# Matched with person_9 (distance: 0.57)
# Matched with person_15 (distance: 0.52)
# Matched with person_42 (distance: 0.57)
# Matched with person_2 (distance: 0.38)
# Matched with person_4 (distance: 0.46)
# Matched with person_37 (distance: 0.59)
# Matched with person_3 (distance: 0.54)
# Matched with person_32 (distance: 0.54)
# Matched with person_26 (distance: 0.54)
# Matched with person_7 (distance: 0.56)
# Matched with person_33 (distance: 0.50)
# Matched with person_18 (distance: 0.53)
# Video video_265.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_265.mp4 processed and deleted.
# Total number of unique faces detected in video_265.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-1119272995406354
# Matched with person_6 (distance: 0.11)
# Matched with person_7 (distance: 0.20)
# Matched with person_8 (distance: 0.27)
# Matched with person_4 (distance: 0.51)
# Matched with person_48 (distance: 0.51)
# Matched with person_2 (distance: 0.44)
# Video video_266.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_266.mp4 processed and deleted.
# Total number of unique faces detected in video_266.mp4: 52
# Downloaded video from https://fgimagestorage.blob.core.windows.net/facebook-assets/hd-1118763132933218
# Video video_267.mp4 has ended.
# Encodings saved to /content/known_faces.json
# Video video_267.mp4 processed and deleted.
# Total number of unique faces detected in video_267.mp4: 52
# Updated Excel file saved as updated_video_performance_with_people.xlsx

# %% [markdown]
# #Totally 52 Unique face / Influencer Detected

# %% [markdown]
# #Analysis Part

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel(r"/content/updated_video_performance_with_people.xlsx")

# %%
df['People Detected'] = df['People Detected'].fillna('')
df['People Detected'] = df['People Detected'].apply(lambda x: [name.strip() for name in x.split(',') if name])
df_exploded = df.explode('People Detected')

# %%
df_exploded
# Out:
#      Performance                                          Video URL  \
# 0       1.106000  https://fgimagestorage.blob.core.windows.net/f...
# 1       2.244700  https://fgimagestorage.blob.core.windows.net/f...
# 2       2.012600  https://fgimagestorage.blob.core.windows.net/f...
# 2       2.012600  https://fgimagestorage.blob.core.windows.net/f...
# 2       2.012600  https://fgimagestorage.blob.core.windows.net/f...
# ..           ...                                                ...
# 266     0.156167  https://fgimagestorage.blob.core.windows.net/f...
# 266     0.156167  https://fgimagestorage.blob.core.windows.net/f...
# 266     0.156167  https://fgimagestorage.blob.core.windows.net/f...
# 266     0.156167  https://fgimagestorage.blob.core.windows.net/f...
# 267     1.444243  https://fgimagestorage.blob.core.windows.net/f...
#
#     People Detected  Number of New Faces Detected
# 0          person_1                             1
# 1               NaN                             0
# 2          person_2                             4
# 2          person_3                             4
# 2          person_4                             4
# ..              ...                           ...
# 266        person_8                             0
# 266        person_4                             0
# 266       person_48                             0
# 266        person_2                             0
# 267             NaN                             0
#
# [877 rows x 4 columns]

# %%
df_exploded['People Detected'] = df_exploded['People Detected'].fillna('')
df_exploded = df_exploded[df_exploded['People Detected'] != ""]
# Out:
#      Performance                                          Video URL  \
# 0       1.106000  https://fgimagestorage.blob.core.windows.net/f...
# 2       2.012600  https://fgimagestorage.blob.core.windows.net/f...
# 2       2.012600  https://fgimagestorage.blob.core.windows.net/f...
# 2       2.012600  https://fgimagestorage.blob.core.windows.net/f...
# 2       2.012600  https://fgimagestorage.blob.core.windows.net/f...
# ..           ...                                                ...
# 266     0.156167  https://fgimagestorage.blob.core.windows.net/f...
# 266     0.156167  https://fgimagestorage.blob.core.windows.net/f...
# 266     0.156167  https://fgimagestorage.blob.core.windows.net/f...
# 266     0.156167  https://fgimagestorage.blob.core.windows.net/f...
# 266     0.156167  https://fgimagestorage.blob.core.windows.net/f...
#
#     People Detected  Number of New Faces Detected
# 0          person_1                             1
# 2          person_2                             4
# 2          person_3                             4
# 2          person_4                             4
# 2          person_5                             4
# ..              ...                           ...
# 266        person_7                             0
# 266        person_8                             0
# 266        person_4                             0
# 266       person_48                             0
# 266        person_2                             0
#
# [828 rows x 4 columns]

# %%
stats = df_exploded.groupby('People Detected').agg(
    Mean_Performance=('Performance', 'mean'),
    Median_Performance=('Performance', 'median'),
    Std_Deviation=('Performance', 'std'),
    Appearances=('Performance', 'count')
).reset_index()
stats
# Out:
#    People Detected  Mean_Performance  Median_Performance  Std_Deviation  \
# 0         person_1          1.062443            0.976586       0.620232
# 1        person_10          0.911185            0.912767       0.627385
# 2        person_11          0.895274            0.677700       0.618856
# 3        person_12          0.854684            0.741103       0.628333
# 4        person_13          0.944641            0.826000       0.574970
# 5        person_14          1.011952            0.695585       0.967461
# 6        person_15          0.912431            0.720853       0.602291
# 7        person_16          1.369262            1.530400       0.718496
# 8        person_17          1.246366            1.241732       0.938958
# 9        person_18          1.059367            1.070043       0.639565
# 10       person_19          0.738971            0.532700       0.583020
# 11        person_2          0.940948            0.926716       0.623877
# 12       person_20          0.457333            0.381400       0.369165
# 13       person_21          0.657069            0.515800       0.537698
# 14       person_22          0.622237            0.515800       0.464850
# 15       person_23          0.691174            0.549600       0.505019
# 16       person_24          1.131772            1.356265       0.446699
# 17       person_25          0.911580            1.274918       0.550407
# 18       person_26          0.893874            0.741103       0.568007
# 19       person_27          0.605524            0.741103       0.474906
# 20       person_28          0.979455            1.376463       0.698755
# 21       person_29          0.705630            0.527749       0.568096
# 22        person_3          0.908117            0.917796       0.585106
# 23       person_30          0.771186            0.829449       0.506792
# 24       person_31          0.481303            0.237227       0.601697
# 25       person_32          0.746671            0.741103       0.543723
# 26       person_33          0.564306            0.382610       0.535841
# 27       person_34          0.182917            0.235454       0.094085
# 28       person_35          0.156648            0.156648       0.116463
# 29       person_36          0.563253            0.239000       0.709059
# 30       person_37          0.744834            0.664099       0.603783
# 31       person_38          0.826000            0.826000            NaN
# 32       person_39          0.851478            0.948489       0.622406
# 33        person_4          0.849049            0.695585       0.619495
# 34       person_40          0.826566            0.948489       0.613141
# 35       person_41          0.965578            1.274918       0.596071
# 36       person_42          1.090797            1.227739       0.462030
# 37       person_43          1.376463            1.376463            NaN
# 38       person_44          1.376463            1.376463            NaN
# 39       person_45          0.527749            0.527749            NaN
# 40       person_46          0.527749            0.527749            NaN
# 41       person_47          1.064524            1.064524       0.164099
# 42       person_48          0.726060            0.625377       0.552461
# 43       person_49          0.741103            0.741103            NaN
# 44        person_5          1.135132            1.331761       0.624501
# 45       person_50          0.741103            0.741103            NaN
# 46       person_51          0.287683            0.287683            NaN
# 47       person_52          0.533140            0.533140            NaN
# 48        person_6          0.877646            0.853600       0.575054
# 49        person_7          0.863093            0.842936       0.564158
# 50        person_8          0.882865            0.842936       0.609924
# 51        person_9          0.779765            0.771181       0.469045
#
#     Appearances
# 0            89
# 1            17
# 2            11
# 3            19
# 4             7
# 5             5
# 6            20
# 7             9
# 8             4
# 9            17
# 10            8
# 11           90
# 12            9
# 13           11
# 14            9
# 15            7
# 16            6
# 17            9
# 18           19
# 19            7
# 20            7
# 21            9
# 22           35
# 23           12
# 24            4
# 25            9
# 26            7
# 27            3
# 28            2
# 29            3
# 30           12
# 31            1
# 32            9
# 33           61
# 34            7
# 35            5
# 36            6
# 37            1
# 38            1
# 39            1
# 40            1
# 41            2
# 42           11
# 43            1
# 44           11
# 45            1
# 46            1
# 47            1
# 48           73
# 49           66
# 50           76
# 51           16

# %% [markdown]
# It seems like you've summarized the performance statistics for influencers based on their appearances in the dataset. Here’s how you can interpret and proceed with this data:
#
# ### Key Metrics:
# 1. **Mean Performance:** Represents the average engagement generated by the influencer.
# 2. **Median Performance:** Indicates the middle point of performance and is useful for understanding central tendency, especially if there are outliers.
# 3. **Standard Deviation (Std_Deviation):** Reflects the consistency of the influencer's performance. Lower values suggest consistent engagement.
# 4. **Appearances:** Shows the number of times the influencer appears in the dataset, which can help gauge reliability.
#
# ---
#
# ### Suggestions to Choose Influencers:
# 1. **Consistency and High Average Performance:**
#    - Look for influencers with high **Mean Performance** and low **Std_Deviation.**
#    - Example: `person_42` (Mean Performance: 1.09, Std_Deviation: 0.46) and `person_24` (Mean Performance: 1.13, Std_Deviation: 0.44).
#
# 2. **Sufficient Appearances:**
#    - Avoid influencers with very few appearances as their performance metrics may not be reliable.
#    - Example: Focus on influencers with at least 10 appearances, such as `person_1` (89 appearances) or `person_2` (90 appearances).
#
# 3. **Balanced Strategy:**
#    - Combine influencers with high performance and those who are consistent across campaigns for a balanced approach.
#
# ---
#
# ### Actionable Steps:
# 1. **Rank Influencers:**
#    - Create a ranking by weighting the metrics (e.g., Mean Performance contributes 50%, Median 30%, and Std_Deviation consistency 20%).
#    - Normalize values for proper comparison.
#
# 2. **Visualize Results:**
#    - Plot influencers’ Mean Performance against Std_Deviation for easy identification of high-performing, consistent influencers.
#    - Use a bubble chart to include **Appearances** as bubble size.
#
# 3. **Filter Low Performers:**
#    - Exclude influencers with Mean Performance below a threshold (e.g., 0.7) or Std_Deviation above a threshold (e.g., 0.7).
